# %%
import requests
import json

# %%
API_KEY = '' #insert your own API KEY

SPORT = 'upcoming' # use the sport_key from the /sports endpoint below, or use 'upcoming' to see the next 8 games across all sports

REGIONS = 'uk' # uk | us | eu | au. Use comma-seperation to use multiple

MARKETS = 'h2h,spreads,totals' # h2h | spreads | totals ^

ODDS_FORMAT = 'decimal' # decimal | american

DATE_FORMAT = 'iso' # iso | unix

# %%
odds_response = requests.get(
    f'https://api.the-odds-api.com/v4/sports/{SPORT}/odds',
    params={
        'api_key': API_KEY,
        'regions': REGIONS,
        'markets': MARKETS,
        'oddsFormat': ODDS_FORMAT,
        'dateFormat': DATE_FORMAT,
    }
)

if odds_response.status_code != 200:
    print(f'Failed to get odds: status_code {odds_response.status_code}, response body {odds_response.text}')

else:
    odds_json = odds_response.json()
    print('Number of events:', len(odds_json))
    print(json.dumps(odds_json, indent=4))

    # Check the usage quota
    print('Remaining requests', odds_response.headers['x-requests-remaining'])
    print('Used requests', odds_response.headers['x-requests-used'])
# Out:
# Number of events: 25
# [
#     {
#         "id": "46bdcbf099fcccf825e83c31cc8c1688",
#         "sport_key": "baseball_mlb",
#         "sport_title": "MLB",
#         "commence_time": "2024-05-18T23:15:39Z",
#         "home_team": "Texas Rangers",
#         "away_team": "Los Angeles Angels",
#         "bookmakers": [
#             {
#                 "key": "paddypower",
#                 "title": "Paddy Power",
#                 "last_update": "2024-05-19T02:33:42Z",
#                 "markets": [
#                     {
#                         "key": "h2h",
#                         "last_update": "2024-05-19T02:33:42Z",
#                         "outcomes": [
#                             {
#                                 "name": "Los Angeles Angels",
#                                 "price": 1.8
#                             },
#                             {
#                                 "name": "Texas Rangers",
#                                 "price": 1.95
#                             }
#                         ]
#                     }
#                 ]
#             },
#             {
#                 "key": "sport888",
#                 "title": "888sport",
#                 "last_update": "2024-05-19T02:33:43Z",
#                 "markets": [
#                     {
#                         "key": "h2h",
#                         "last_update": "2024-05-19T02:33:43Z",
#                         "outcomes": [
#                             {
#                                 "name": "Los Angeles Angels",
#                                 "price": 1.67
#                             },
#                             {
#                                 "name": "Texas Rangers",
#                                 "price": 2.05
#                             }
#                         ]
#                     },
#                     {
#                         "key": "spreads",
#                         "last_update": "2024-05-19T02:33:43Z",
#                         "outcomes": [
#                             {
#                                 "name": "Los Angeles Angels",
#                                 "price": 2.5,
#                                 "point": -1.5
#                             },
#                             {
#                                 "name": "Texas Rangers",
#                                 "price": 1.44,
#                                 "point": 1.5
#                             }
#                         ]
#                     },
#                     {
#                         "key": "totals",
#                         "last_update": "2024-05-19T02:33:43Z",
#                         "outcomes": [
#                             {
#                                 "name": "Over",
#                                 "price": 1.57,
#                                 "point": 6.5
#                             },
#                             {
#                                 "name": "Under",
#                                 "price": 2.25,
#                                 "point": 6.5
#                             }
#                         ]
#                     }
#                 ]
#             },
#             {
#                 "key": "livescorebet",
#                 "title": "LiveScore Bet",
#                 "last_update": "2024-05-19T02:33:43Z",
#                 "markets": [
#                     {
#                         "key": "h2h",
#                         "last_update": "2024-05-19T02:33:43Z",
#                         "outcomes": [
#                             {
#                                 "name": "Los Angeles Angels",
#                                 "price": 1.77
#                             },
#                             {
#                                 "name": "Texas Rangers",
#                                 "price": 2.0
#                             }
#                         ]
#                     }
#                 ]
#             },
#             {
#                 "key": "virginbet",
#                 "title": "Virgin Bet",
#                 "last_update": "2024-05-19T02:33:43Z",
#                 "markets": [
#                     {
#                         "key": "h2h",
#                         "last_update": "2024-05-19T02:33:43Z",
#                         "outcomes": [
#                             {
#                                 "name": "Los Angeles Angels",
#                                 "price": 1.77
#                             },
#                             {
#                                 "name": "Texas Rangers",
#                                 "price": 2.0
#                             }
#                         ]
#                     }
#                 ]
#             },
#             {
#                 "key": "betfair_sb_uk",
#                 "title": "Betfair Sportsbook",
#                 "last_update": "2024-05-19T02:33:44Z",
#                 "markets": [
#                     {
#                         "key": "h2h",
#                         "last_update": "2024-05-19T02:33:44Z",
#                         "outcomes": [
#                             {
#                                 "name": "Los Angeles Angels",
#                                 "price": 1.7
#                             },
#                             {
#                                 "name": "Texas Rangers",
#                                 "price": 2.0
#                             }
#                         ]
#                     }
#                 ]
#             },
#             {
#                 "key": "casumo",
#                 "title": "Casumo",
#                 "last_update": "2024-05-19T02:33:43Z",
#                 "markets": [
#                     {
#                         "key": "h2h",
#                         "last_update": "2024-05-19T02:33:43Z",
#                         "outcomes": [
#                             {
#                                 "name": "Los Angeles Angels",
#                                 "price": 1.67
#                             },
#                             {
#                                 "name": "Texas Rangers",
#                                 "price": 2.18
#                             }
#                         ]
#                     }
#                 ]
#             },
#             {
#                 "key": "mrgreen",
#                 "title": "Mr Green",
#                 "last_update": "2024-05-19T02:33:43Z",
#                 "markets": [
#                     {
#                         "key": "h2h",
#                         "last_update": "2024-05-19T02:33:43Z",
#                         "outcomes": [
#                             {
#                                 "name": "Los Angeles Angels",
#                                 "price": 1.64
#                             },
#                             {
#                                 "name": "Texas Rangers",
#                                 "price": 2.12
#                             }
#                         ]
#                     }
#                 ]
#             },
#             {
#                 "key": "leovegas",
#                 "title": "LeoVegas",
#                 "last_update": "2024-05-19T02:33:43Z",
#                 "markets": [
#                     {
#                         "key": "h2h",
#                         "last_update": "2024-05-19T02:33:43Z",
#                         "outcomes": [
#                             {
#                                 "name": "Los Angeles Angels",
#                                 "price": 1.57
#                             },
#                             {
#                                 "name": "Texas Rangers",
#                                 "price": 2.06
#                             }
#                         ]
#                     }
#                 ]
#             },
#             {
#                 "key": "unibet_uk",
#                 "title": "Unibet",
#                 "last_update": "2024-05-19T02:33:44Z",
#                 "markets": [
#                     {
#                         "key": "h2h",
#                         "last_update": "2024-05-19T02:33:44Z",
#                         "outcomes": [
#                             {
#                                 "name": "Los Angeles Angels",
#                                 "price": 1.67
#                             },
#                             {
#                                 "name": "Texas Rangers",
#                                 "price": 2.18
#                             }
#                         ]
#                     }
#                 ]
#             },
#             {
#                 "key": "grosvenor",
#                 "title": "Grosvenor",
#                 "last_update": "2024-05-19T02:33:44Z",
#                 "markets": [
#                     {
#                         "key": "h2h",
#                         "last_update": "2024-05-19T02:33:44Z",
#                         "outcomes": [
#                             {
#                                 "name": "Los Angeles Angels",
#                                 "price": 1.67
#                             },
#                             {
#                                 "name": "Texas Rangers",
#                                 "price": 2.18
#                             }
#                         ]
#                     }
#                 ]
#             },
#             {
#                 "key": "betfair_ex_uk",
#                 "title": "Betfair",
#                 "last_update": "2024-05-19T02:34:20Z",
#                 "markets": [
#                     {
#                         "key": "h2h",
#                         "last_update": "2024-05-19T02:34:20Z",
#                         "outcomes": [
#                             {
#                                 "name": "Los Angeles Angels",
#                                 "price": 2.08
#                             },
#                             {
#                                 "name": "Texas Rangers",
#                                 "price": 1.56
#                             }
#                         ]
#                     },
#                     {
#                         "key": "h2h_lay",
#                         "last_update": "2024-05-19T02:34:20Z",
#                         "outcomes": [
#                             {
#                                 "name": "Los Angeles Angels",
#                                 "price": 2.76
#                             },
#                             {
#                                 "name": "Texas Rangers",
#                                 "price": 1.93
#                             }
#                         ]
#                     }
#                 ]
#             }
#         ]
#     },
#     {
#         "id": "03ba27aad9c18caf8a1f9eb55f5b76cb",
#         "sport_key": "americanfootball_ufl",
#         "sport_title": "UFL",
#         "commence_time": "2024-05-19T00:04:43Z",
#         "home_team": "Birmingham Stallions",
#         "away_team": "Houston Roughnecks",
#         "bookmakers": []
#     },
#     {
#         "id": "d81e3511d8112dc197da043183f9b403",
#         "sport_key": "icehockey_nhl",
#         "sport_title": "NHL",
#         "commence_time": "2024-05-19T00:10:00Z",
#         "home_team": "Edmonton Oilers",
#         "away_team": "Vancouver Canucks",
#         "bookmakers": [
#             {
#                 "key": "virginbet",
#                 "title": "Virgin Bet",
#                 "last_update": "2024-05-19T02:33:35Z",
#                 "markets": [
#                     {
#                         "key": "spreads",
#                         "last_update": "2024-05-19T02:33:35Z",
#                         "outcomes": [
#                             {
#                                 "name": "Edmonton Oilers",
#                                 "price": 1.8,
#                                 "point": -3.5
#                             },
#                             {
#                                 "name": "Vancouver Canucks",
#                                 "price": 1.95,
#                                 "point": 3.5
#                             }
#                         ]
#                     },
#                     {
#                         "key": "totals",
#                         "last_update": "2024-05-19T02:33:35Z",
#                         "outcomes": [
#                             {
#                                 "name": "Over",
#                                 "price": 2.55,
#                                 "point": 6.5
#                             },
#                             {
#                                 "name": "Under",
#                                 "price": 1.5,
#                                 "point": 6.5
#                             }
#                         ]
#                     }
#                 ]
#             },
#             {
#                 "key": "livescorebet",
#                 "title": "LiveScore Bet",
#                 "last_update": "2024-05-19T02:33:35Z",
#                 "markets": [
#                     {
#                         "key": "spreads",
#                         "last_update": "2024-05-19T02:33:35Z",
#                         "outcomes": [
#                             {
#                                 "name": "Edmonton Oilers",
#                                 "price": 1.8,
#                                 "point": -3.5
#                             },
#                             {
#                                 "name": "Vancouver Canucks",
#                                 "price": 1.95,
#                                 "point": 3.5
#                             }
#                         ]
#                     },
#                     {
#                         "key": "totals",
#                         "last_update": "2024-05-19T02:33:35Z",
#                         "outcomes": [
#                             {
#                                 "name": "Over",
#                                 "price": 2.55,
#                                 "point": 6.5
#                             },
#                             {
#                                 "name": "Under",
#                                 "price": 1.5,
#                                 "point": 6.5
#                             }
#                         ]
#                     }
#                 ]
#             },
#             {
#                 "key": "leovegas",
#                 "title": "LeoVegas",
#                 "last_update": "2024-05-19T02:33:35Z",
#                 "markets": [
#                     {
#                         "key": "spreads",
#                         "last_update": "2024-05-19T02:33:35Z",
#                         "outcomes": [
#                             {
#                                 "name": "Edmonton Oilers",
#                                 "price": 1.67,
#                                 "point": -3.5
#                             },
#                             {
#                                 "name": "Vancouver Canucks",
#                                 "price": 1.88,
#                                 "point": 3.5
#                             }
#                         ]
#                     },
#                     {
#                         "key": "totals",
#                         "last_update": "2024-05-19T02:33:35Z",
#                         "outcomes": [
#                             {
#                                 "name": "Over",
#                                 "price": 2.4,
#                                 "point": 6.5
#                             },
#                             {
#                                 "name": "Under",
#                                 "price": 1.4,
#                                 "point": 6.5
#                             }
#                         ]
#                     }
#                 ]
#             },
#             {
#                 "key": "casumo",
#                 "title": "Casumo",
#                 "last_update": "2024-05-19T02:33:35Z",
#                 "markets": [
#                     {
#                         "key": "spreads",
#                         "last_update": "2024-05-19T02:33:35Z",
#                         "outcomes": [
#                             {
#                                 "name": "Edmonton Oilers",
#                                 "price": 1.76,
#                                 "point": -3.5
#                             },
#                             {
#                                 "name": "Vancouver Canucks",
#                                 "price": 2.0,
#                                 "point": 3.5
#                             }
#                         ]
#                     },
#                     {
#                         "key": "totals",
#                         "last_update": "2024-05-19T02:33:35Z",
#                         "outcomes": [
#                             {
#                                 "name": "Over",
#                                 "price": 2.55,
#                                 "point": 6.5
#                             },
#                             {
#                                 "name": "Under",
#                                 "price": 1.47,
#                                 "point": 6.5
#                             }
#                         ]
#                     }
#                 ]
#             },
#             {
#                 "key": "unibet_uk",
#                 "title": "Unibet",
#                 "last_update": "2024-05-19T02:33:35Z",
#                 "markets": [
#                     {
#                         "key": "spreads",
#                         "last_update": "2024-05-19T02:33:35Z",
#                         "outcomes": [
#                             {
#                                 "name": "Edmonton Oilers",
#                                 "price": 1.76,
#                                 "point": -3.5
#                             },
#                             {
#                                 "name": "Vancouver Canucks",
#                                 "price": 2.0,
#                                 "point": 3.5
#                             }
#                         ]
#                     },
#                     {
#                         "key": "totals",
#                         "last_update": "2024-05-19T02:33:35Z",
#                         "outcomes": [
#                             {
#                                 "name": "Over",
#                                 "price": 2.55,
#                                 "point": 6.5
#                             },
#                             {
#                                 "name": "Under",
#                                 "price": 1.47,
#                                 "point": 6.5
#                             }
#                         ]
#                     }
#                 ]
#             },
#             {
#                 "key": "grosvenor",
#                 "title": "Grosvenor",
#                 "last_update": "2024-05-19T02:33:35Z",
#                 "markets": [
#                     {
#                         "key": "spreads",
#                         "last_update": "2024-05-19T02:33:35Z",
#                         "outcomes": [
#                             {
#                                 "name": "Edmonton Oilers",
#                                 "price": 1.76,
#                                 "point": -3.5
#                             },
#                             {
#                                 "name": "Vancouver Canucks",
#                                 "price": 2.0,
#                                 "point": 3.5
#                             }
#                         ]
#                     },
#                     {
#                         "key": "totals",
#                         "last_update": "2024-05-19T02:33:35Z",
#                         "outcomes": [
#                             {
#                                 "name": "Over",
#                                 "price": 2.55,
#                                 "point": 6.5
#                             },
#                             {
#                                 "name": "Under",
#                                 "price": 1.47,
#                                 "point": 6.5
#                             }
#                         ]
#                     }
#                 ]
#             },
#             {
#                 "key": "betway",
#                 "title": "Betway",
#                 "last_update": "2024-05-19T02:31:23Z",
#                 "markets": [
#                     {
#                         "key": "h2h",
#                         "last_update": "2024-05-19T02:31:23Z",
#                         "outcomes": [
#                             {
#                                 "name": "Edmonton Oilers",
#                                 "price": 1.01
#                             },
#                             {
#                                 "name": "Vancouver Canucks",
#                                 "price": 31.0
#                             },
#                             {
#                                 "name": "Draw",
#                                 "price": 11.0
#                             }
#                         ]
#                     }
#                 ]
#             },
#             {
#                 "key": "matchbook",
#                 "title": "Matchbook",
#                 "last_update": "2024-05-19T02:21:34Z",
#                 "markets": [
#                     {
#                         "key": "h2h",
#                         "last_update": "2024-05-19T02:21:34Z",
#                         "outcomes": [
#                             {
#                                 "name": "Edmonton Oilers",
#                                 "price": 1.03
#                             },
#                             {
#                                 "name": "Vancouver Canucks",
#                                 "price": 3.0
#                             }
#                         ]
#                     },
#                     {
#                         "key": "h2h_lay",
#                         "last_update": "2024-05-19T02:21:34Z",
#                         "outcomes": [
#                             {
#                                 "name": "Edmonton Oilers",
#                                 "price": 1.5
#                             },
#                             {
#                                 "name": "Vancouver Canucks",
#                                 "price": 36.0
#                             }
#                         ]
#                     }
#                 ]
#             }
#         ]
#     },
#     {
#         "id": "bc64bea8f35a5c1565a32d067b85a5d9",
#         "sport_key": "baseball_mlb",
#         "sport_title": "MLB",
#         "commence_time": "2024-05-19T00:10:10Z",
#         "home_team": "Arizona Diamondbacks",
#         "away_team": "Detroit Tigers",
#         "bookmakers": [
#             {
#                 "key": "paddypower",
#                 "title": "Paddy Power",
#                 "last_update": "2024-05-19T02:24:05Z",
#                 "markets": [
#                     {
#                         "key": "h2h",
#                         "last_update": "2024-05-19T02:24:05Z",
#                         "outcomes": [
#                             {
#                                 "name": "Arizona Diamondbacks",
#                                 "price": 17.0
#                             },
#                             {
#                                 "name": "Detroit Tigers",
#                                 "price": 1.0
#                             }
#                         ]
#                     }
#                 ]
#             },
#             {
#                 "key": "sport888",
#                 "title": "888sport",
#                 "last_update": "2024-05-19T02:33:43Z",
#                 "markets": [
#                     {
#                         "key": "spreads",
#                         "last_update": "2024-05-19T02:33:43Z",
#                         "outcomes": [
#                             {
#                                 "name": "Arizona Diamondbacks",
#                                 "price": 2.0,
#                                 "point": 5.5
#                             },
#                             {
#                                 "name": "Detroit Tigers",
#                                 "price": 1.7,
#                                 "point": -5.5
#                             }
#                         ]
#                     },
#                     {
#                         "key": "totals",
#                         "last_update": "2024-05-19T02:33:43Z",
#                         "outcomes": [
#                             {
#                                 "name": "Over",
#                                 "price": 2.3,
#                                 "point": 11.5
#                             },
#                             {
#                                 "name": "Under",
#                                 "price": 1.53,
#                                 "point": 11.5
#                             }
#                         ]
#                     }
#                 ]
#             },
#             {
#                 "key": "livescorebet",
#                 "title": "LiveScore Bet",
#                 "last_update": "2024-05-19T02:33:43Z",
#                 "markets": [
#                     {
#                         "key": "totals",
#                         "last_update": "2024-05-19T02:33:43Z",
#                         "outcomes": [
#                             {
#                                 "name": "Over",
#                                 "price": 2.45,
#                                 "point": 11.5
#                             },
#                             {
#                                 "name": "Under",
#                                 "price": 1.53,
#                                 "point": 11.5
#                             }
#                         ]
#                     }
#                 ]
#             },
#             {
#                 "key": "virginbet",
#                 "title": "Virgin Bet",
#                 "last_update": "2024-05-19T02:33:43Z",
#                 "markets": [
#                     {
#                         "key": "totals",
#                         "last_update": "2024-05-19T02:33:43Z",
#                         "outcomes": [
#                             {
#                                 "name": "Over",
#                                 "price": 2.45,
#                                 "point": 11.5
#                             },
#                             {
#                                 "name": "Under",
#                                 "price": 1.53,
#                                 "point": 11.5
#                             }
#                         ]
#                     }
#                 ]
#             },
#             {
#                 "key": "betway",
#                 "title": "Betway",
#                 "last_update": "2024-05-19T02:34:21Z",
#                 "markets": [
#                     {
#                         "key": "h2h",
#                         "last_update": "2024-05-19T02:34:21Z",
#                         "outcomes": [
#                             {
#                                 "name": "Arizona Diamondbacks",
#                                 "price": 16.0
#                             },
#                             {
#                                 "name": "Detroit Tigers",
#                                 "price": 1.01
#                             }
#                         ]
#                     }
#                 ]
#             },
#             {
#                 "key": "casumo",
#                 "title": "Casumo",
#                 "last_update": "2024-05-19T02:33:43Z",
#                 "markets": [
#                     {
#                         "key": "spreads",
#                         "last_update": "2024-05-19T02:33:43Z",
#                         "outcomes": [
#                             {
#                                 "name": "Arizona Diamondbacks",
#                                 "price": 2.25,
#                                 "point": 5.5
#                             },
#                             {
#                                 "name": "Detroit Tigers",
#                                 "price": 1.62,
#                                 "point": -5.5
#                             }
#                         ]
#                     }
#                 ]
#             },
#             {
#                 "key": "mrgreen",
#                 "title": "Mr Green",
#                 "last_update": "2024-05-19T02:31:50Z",
#                 "markets": [
#                     {
#                         "key": "totals",
#                         "last_update": "2024-05-19T02:31:50Z",
#                         "outcomes": [
#                             {
#                                 "name": "Over",
#                                 "price": 1.96,
#                                 "point": 11.5
#                             },
#                             {
#                                 "name": "Under",
#                                 "price": 1.72,
#                                 "point": 11.5
#                             }
#                         ]
#                     }
#                 ]
#             },
#             {
#                 "key": "leovegas",
#                 "title": "LeoVegas",
#                 "last_update": "2024-05-19T02:19:38Z",
#                 "markets": [
#                     {
#                         "key": "h2h",
#                         "last_update": "2024-05-19T02:19:38Z",
#                         "outcomes": [
#                             {
#                                 "name": "Arizona Diamondbacks",
#                                 "price": 5.3
#                             },
#                             {
#                                 "name": "Detroit Tigers",
#                                 "price": 1.08
#                             }
#                         ]
#                     }
#                 ]
#             },
#             {
#                 "key": "unibet_uk",
#                 "title": "Unibet",
#                 "last_update": "2024-05-19T02:19:38Z",
#                 "markets": [
#                     {
#                         "key": "h2h",
#                         "last_update": "2024-05-19T02:19:38Z",
#                         "outcomes": [
#                             {
#                                 "name": "Arizona Diamondbacks",
#                                 "price": 6.25
#                             },
#                             {
#                                 "name": "Detroit Tigers",
#                                 "price": 1.12
#                             }
#                         ]
#                     }
#                 ]
#             },
#             {
#                 "key": "grosvenor",
#                 "title": "Grosvenor",
#                 "last_update": "2024-05-19T02:33:44Z",
#                 "markets": [
#                     {
#                         "key": "spreads",
#                         "last_update": "2024-05-19T02:33:44Z",
#                         "outcomes": [
#                             {
#                                 "name": "Arizona Diamondbacks",
#                                 "price": 2.25,
#                                 "point": 5.5
#                             },
#                             {
#                                 "name": "Detroit Tigers",
#                                 "price": 1.62,
#                                 "point": -5.5
#                             }
#                         ]
#                     }
#                 ]
#             },
#             {
#                 "key": "betfair_sb_uk",
#                 "title": "Betfair Sportsbook",
#                 "last_update": "2024-05-19T02:24:06Z",
#                 "markets": [
#                     {
#                         "key": "h2h",
#                         "last_update": "2024-05-19T02:24:06Z",
#                         "outcomes": [
#                             {
#                                 "name": "Arizona Diamondbacks",
#                                 "price": 17.0
#                             },
#                             {
#                                 "name": "Detroit Tigers",
#                                 "price": 1.01
#                             }
#                         ]
#                     }
#                 ]
#             },
#             {
#                 "key": "betfair_ex_uk",
#                 "title": "Betfair",
#                 "last_update": "2024-05-19T02:26:21Z",
#                 "markets": [
#                     {
#                         "key": "h2h",
#                         "last_update": "2024-05-19T02:26:21Z",
#                         "outcomes": [
#                             {
#                                 "name": "Arizona Diamondbacks",
#                                 "price": 19.5
#                             },
#                             {
#                                 "name": "Detroit Tigers",
#                                 "price": 1.01
#                             }
#                         ]
#                     },
#                     {
#                         "key": "h2h_lay",
#                         "last_update": "2024-05-19T02:26:21Z",
#                         "outcomes": [
#                             {
#                                 "name": "Arizona Diamondbacks",
#                                 "price": 110.0
#                             },
#                             {
#                                 "name": "Detroit Tigers",
#                                 "price": 1.06
#                             }
#                         ]
#                     }
#                 ]
#             }
#         ]
#     },
#     {
#         "id": "127b8c3c6f1fada94c4a10873fdac809",
#         "sport_key": "basketball_nba",
#         "sport_title": "NBA",
#         "commence_time": "2024-05-19T00:13:51Z",
#         "home_team": "Dallas Mavericks",
#         "away_team": "Oklahoma City Thunder",
#         "bookmakers": [
#             {
#                 "key": "virginbet",
#                 "title": "Virgin Bet",
#                 "last_update": "2024-05-19T02:33:56Z",
#                 "markets": [
#                     {
#                         "key": "h2h",
#                         "last_update": "2024-05-19T02:33:56Z",
#                         "outcomes": [
#                             {
#                                 "name": "Dallas Mavericks",
#                                 "price": 1.2
#                             },
#                             {
#                                 "name": "Oklahoma City Thunder",
#                                 "price": 4.2
#                             }
#                         ]
#                     },
#                     {
#                         "key": "spreads",
#                         "last_update": "2024-05-19T02:33:56Z",
#                         "outcomes": [
#                             {
#                                 "name": "Dallas Mavericks",
#                                 "price": 1.95,
#                                 "point": -2.5
#                             },
#                             {
#                                 "name": "Oklahoma City Thunder",
#                                 "price": 1.8,
#                                 "point": 2.5
#                             }
#                         ]
#                     },
#                     {
#                         "key": "totals",
#                         "last_update": "2024-05-19T02:33:56Z",
#                         "outcomes": [
#                             {
#                                 "name": "Over",
#                                 "price": 2.0,
#                                 "point": 232.5
#                             },
#                             {
#                                 "name": "Under",
#                                 "price": 1.77,
#                                 "point": 232.5
#                             }
#                         ]
#                     }
#                 ]
#             },
#             {
#                 "key": "livescorebet",
#                 "title": "LiveScore Bet",
#                 "last_update": "2024-05-19T02:33:56Z",
#                 "markets": [
#                     {
#                         "key": "h2h",
#                         "last_update": "2024-05-19T02:33:56Z",
#                         "outcomes": [
#                             {
#                                 "name": "Dallas Mavericks",
#                                 "price": 1.2
#                             },
#                             {
#                                 "name": "Oklahoma City Thunder",
#                                 "price": 4.2
#                             }
#                         ]
#                     },
#                     {
#                         "key": "spreads",
#                         "last_update": "2024-05-19T02:33:56Z",
#                         "outcomes": [
#                             {
#                                 "name": "Dallas Mavericks",
#                                 "price": 1.95,
#                                 "point": -2.5
#                             },
#                             {
#                                 "name": "Oklahoma City Thunder",
#                                 "price": 1.8,
#                                 "point": 2.5
#                             }
#                         ]
#                     },
#                     {
#                         "key": "totals",
#                         "last_update": "2024-05-19T02:33:56Z",
#                         "outcomes": [
#                             {
#                                 "name": "Over",
#                                 "price": 2.0,
#                                 "point": 232.5
#                             },
#                             {
#                                 "name": "Under",
#                                 "price": 1.77,
#                                 "point": 232.5
#                             }
#                         ]
#                     }
#                 ]
#             },
#             {
#                 "key": "paddypower",
#                 "title": "Paddy Power",
#                 "last_update": "2024-05-19T02:32:45Z",
#                 "markets": [
#                     {
#                         "key": "h2h",
#                         "last_update": "2024-05-19T02:32:45Z",
#                         "outcomes": [
#                             {
#                                 "name": "Dallas Mavericks",
#                                 "price": 1.12
#                             },
#                             {
#                                 "name": "Oklahoma City Thunder",
#                                 "price": 5.5
#                             }
#                         ]
#                     }
#                 ]
#             },
#             {
#                 "key": "sport888",
#                 "title": "888sport",
#                 "last_update": "2024-05-19T02:31:09Z",
#                 "markets": [
#                     {
#                         "key": "h2h",
#                         "last_update": "2024-05-19T02:31:09Z",
#                         "outcomes": [
#                             {
#                                 "name": "Dallas Mavericks",
#                                 "price": 1.75
#                             },
#                             {
#                                 "name": "Oklahoma City Thunder",
#                                 "price": 1.91
#                             }
#                         ]
#                     }
#                 ]
#             },
#             {
#                 "key": "betfair_sb_uk",
#                 "title": "Betfair Sportsbook",
#                 "last_update": "2024-05-19T02:32:46Z",
#                 "markets": [
#                     {
#                         "key": "h2h",
#                         "last_update": "2024-05-19T02:32:46Z",
#                         "outcomes": [
#                             {
#                                 "name": "Dallas Mavericks",
#                                 "price": 1.13
#                             },
#                             {
#                                 "name": "Oklahoma City Thunder",
#                                 "price": 6.0
#                             }
#                         ]
#                     },
#                     {
#                         "key": "spreads",
#                         "last_update": "2024-05-19T02:32:46Z",
#                         "outcomes": [
#                             {
#                                 "name": "Dallas Mavericks",
#                                 "price": 1.83,
#                                 "point": -3.5
#                             },
#                             {
#                                 "name": "Oklahoma City Thunder",
#                                 "price": 1.91,
#                                 "point": 3.5
#                             }
#                         ]
#                     }
#                 ]
#             },
#             {
#                 "key": "coral",
#                 "title": "Coral",
#                 "last_update": "2024-05-19T02:33:57Z",
#                 "markets": [
#                     {
#                         "key": "h2h",
#                         "last_update": "2024-05-19T02:33:57Z",
#                         "outcomes": [
#                             {
#                                 "name": "Dallas Mavericks",
#                                 "price": 1.17
#                             },
#                             {
#                                 "name": "Oklahoma City Thunder",
#                                 "price": 5.0
#                             }
#                         ]
#                     },
#                     {
#                         "key": "spreads",
#                         "last_update": "2024-05-19T02:33:57Z",
#                         "outcomes": [
#                             {
#                                 "name": "Dallas Mavericks",
#                                 "price": 1.7,
#                                 "point": -2.5
#                             },
#                             {
#                                 "name": "Oklahoma City Thunder",
#                                 "price": 2.1,
#                                 "point": 2.5
#                             }
#                         ]
#                     }
#                 ]
#             },
#             {
#                 "key": "casumo",
#                 "title": "Casumo",
#                 "last_update": "2024-05-19T02:31:58Z",
#                 "markets": [
#                     {
#                         "key": "h2h",
#                         "last_update": "2024-05-19T02:31:58Z",
#                         "outcomes": [
#                             {
#                                 "name": "Dallas Mavericks",
#                                 "price": 1.18
#                             },
#                             {
#                                 "name": "Oklahoma City Thunder",
#                                 "price": 4.8
#                             }
#                         ]
#                     }
#                 ]
#             },
#             {
#                 "key": "unibet_uk",
#                 "title": "Unibet",
#                 "last_update": "2024-05-19T02:31:58Z",
#                 "markets": [
#                     {
#                         "key": "h2h",
#                         "last_update": "2024-05-19T02:31:58Z",
#                         "outcomes": [
#                             {
#                                 "name": "Dallas Mavericks",
#                                 "price": 1.18
#                             },
#                             {
#                                 "name": "Oklahoma City Thunder",
#                                 "price": 4.8
#                             }
#                         ]
#                     }
#                 ]
#             },
#             {
#                 "key": "grosvenor",
#                 "title": "Grosvenor",
#                 "last_update": "2024-05-19T02:31:59Z",
#                 "markets": [
#                     {
#                         "key": "h2h",
#                         "last_update": "2024-05-19T02:31:59Z",
#                         "outcomes": [
#                             {
#                                 "name": "Dallas Mavericks",
#                                 "price": 1.18
#                             },
#                             {
#                                 "name": "Oklahoma City Thunder",
#                                 "price": 4.8
#                             }
#                         ]
#                     }
#                 ]
#             },
#             {
#                 "key": "betway",
#                 "title": "Betway",
#                 "last_update": "2024-05-19T02:31:36Z",
#                 "markets": [
#                     {
#                         "key": "h2h",
#                         "last_update": "2024-05-19T02:31:36Z",
#                         "outcomes": [
#                             {
#                                 "name": "Dallas Mavericks",
#                                 "price": 1.25
#                             },
#                             {
#                                 "name": "Oklahoma City Thunder",
#                                 "price": 3.6
#                             }
#                         ]
#                     }
#                 ]
#             },
#             {
#                 "key": "betfair_ex_uk",
#                 "title": "Betfair",
#                 "last_update": "2024-05-19T02:33:57Z",
#                 "markets": [
#                     {
#                         "key": "h2h",
#                         "last_update": "2024-05-19T02:33:57Z",
#                         "outcomes": [
#                             {
#                                 "name": "Dallas Mavericks",
#                                 "price": 1.14
#                             },
#                             {
#                                 "name": "Oklahoma City Thunder",
#                                 "price": 7.6
#                             }
#                         ]
#                     },
#                     {
#                         "key": "h2h_lay",
#                         "last_update": "2024-05-19T02:33:57Z",
#                         "outcomes": [
#                             {
#                                 "name": "Dallas Mavericks",
#                                 "price": 1.15
#                             },
#                             {
#                                 "name": "Oklahoma City Thunder",
#                                 "price": 10.0
#                             }
#                         ]
#                     }
#                 ]
#             },
#             {
#                 "key": "leovegas",
#                 "title": "LeoVegas",
#                 "last_update": "2024-05-19T02:31:58Z",
#                 "markets": [
#                     {
#                         "key": "h2h",
#                         "last_update": "2024-05-19T02:31:58Z",
#                         "outcomes": [
#                             {
#                                 "name": "Dallas Mavericks",
#                                 "price": 1.16
#                             },
#                             {
#                                 "name": "Oklahoma City Thunder",
#                                 "price": 4.4
#                             }
#                         ]
#                     }
#                 ]
#             },
#             {
#                 "key": "matchbook",
#                 "title": "Matchbook",
#                 "last_update": "2024-05-19T02:33:56Z",
#                 "markets": [
#                     {
#                         "key": "h2h",
#                         "last_update": "2024-05-19T02:33:56Z",
#                         "outcomes": [
#                             {
#                                 "name": "Dallas Mavericks",
#                                 "price": 1.16
#                             },
#                             {
#                                 "name": "Oklahoma City Thunder",
#                                 "price": 5.0
#                             }
#                         ]
#                     },
#                     {
#                         "key": "h2h_lay",
#                         "last_update": "2024-05-19T02:33:56Z",
#                         "outcomes": [
#                             {
#                                 "name": "Dallas Mavericks",
#                                 "price": 1.25
#                             },
#                             {
#                                 "name": "Oklahoma City Thunder",
#                                 "price": 7.2
#                             }
#                         ]
#                     }
#                 ]
#             }
#         ]
#     },
#     {
#         "id": "19b74e921a1c4376db69f2f852f249a6",
#         "sport_key": "soccer_usa_mls",
#         "sport_title": "MLS",
#         "commence_time": "2024-05-19T00:40:12Z",
# ...
#                         "key": "totals",
#                         "last_update": "2024-05-19T02:33:55Z",
#                         "outcomes": [
#                             {
#                                 "name": "Over",
#                                 "price": 1.95,
#                                 "point": 6.0
#                             },
#                             {
#                                 "name": "Under",
#                                 "price": 1.8,
#                                 "point": 6.0
#                             }
#                         ]
#                     }
#                 ]
#             }
#         ]
#     },
#     {
#         "id": "c628fa344628badfcebbbcbe0f1ca0cc",
#         "sport_key": "baseball_npb",
#         "sport_title": "NPB",
#         "commence_time": "2024-05-19T05:00:00Z",
#         "home_team": "Yokohama DeNA BayStars",
#         "away_team": "Chunichi Dragons",
#         "bookmakers": [
#             {
#                 "key": "betway",
#                 "title": "Betway",
#                 "last_update": "2024-05-19T02:33:24Z",
#                 "markets": [
#                     {
#                         "key": "h2h",
#                         "last_update": "2024-05-19T02:33:24Z",
#                         "outcomes": [
#                             {
#                                 "name": "Chunichi Dragons",
#                                 "price": 2.05
#                             },
#                             {
#                                 "name": "Yokohama DeNA BayStars",
#                                 "price": 1.69
#                             }
#                         ]
#                     }
#                 ]
#             },
#             {
#                 "key": "sport888",
#                 "title": "888sport",
#                 "last_update": "2024-05-19T02:33:55Z",
#                 "markets": [
#                     {
#                         "key": "h2h",
#                         "last_update": "2024-05-19T02:33:55Z",
#                         "outcomes": [
#                             {
#                                 "name": "Chunichi Dragons",
#                                 "price": 2.1
#                             },
#                             {
#                                 "name": "Yokohama DeNA BayStars",
#                                 "price": 1.67
#                             }
#                         ]
#                     },
#                     {
#                         "key": "spreads",
#                         "last_update": "2024-05-19T02:33:55Z",
#                         "outcomes": [
#                             {
#                                 "name": "Chunichi Dragons",
#                                 "price": 1.44,
#                                 "point": 1.5
#                             },
#                             {
#                                 "name": "Yokohama DeNA BayStars",
#                                 "price": 2.62,
#                                 "point": -1.5
#                             }
#                         ]
#                     },
#                     {
#                         "key": "totals",
#                         "last_update": "2024-05-19T02:33:55Z",
#                         "outcomes": [
#                             {
#                                 "name": "Over",
#                                 "price": 2.0,
#                                 "point": 6.5
#                             },
#                             {
#                                 "name": "Under",
#                                 "price": 1.73,
#                                 "point": 6.5
#                             }
#                         ]
#                     }
#                 ]
#             },
#             {
#                 "key": "livescorebet",
#                 "title": "LiveScore Bet",
#                 "last_update": "2024-05-19T02:33:55Z",
#                 "markets": [
#                     {
#                         "key": "h2h",
#                         "last_update": "2024-05-19T02:33:55Z",
#                         "outcomes": [
#                             {
#                                 "name": "Chunichi Dragons",
#                                 "price": 2.1
#                             },
#                             {
#                                 "name": "Yokohama DeNA BayStars",
#                                 "price": 1.73
#                             }
#                         ]
#                     },
#                     {
#                         "key": "totals",
#                         "last_update": "2024-05-19T02:33:55Z",
#                         "outcomes": [
#                             {
#                                 "name": "Over",
#                                 "price": 1.8,
#                                 "point": 6.0
#                             },
#                             {
#                                 "name": "Under",
#                                 "price": 1.95,
#                                 "point": 6.0
#                             }
#                         ]
#                     }
#                 ]
#             },
#             {
#                 "key": "betfair_sb_uk",
#                 "title": "Betfair Sportsbook",
#                 "last_update": "2024-05-19T02:33:56Z",
#                 "markets": [
#                     {
#                         "key": "h2h",
#                         "last_update": "2024-05-19T02:33:56Z",
#                         "outcomes": [
#                             {
#                                 "name": "Chunichi Dragons",
#                                 "price": 2.1
#                             },
#                             {
#                                 "name": "Yokohama DeNA BayStars",
#                                 "price": 1.67
#                             }
#                         ]
#                     }
#                 ]
#             },
#             {
#                 "key": "williamhill",
#                 "title": "William Hill",
#                 "last_update": "2024-05-19T02:29:45Z",
#                 "markets": [
#                     {
#                         "key": "h2h",
#                         "last_update": "2024-05-19T02:29:45Z",
#                         "outcomes": [
#                             {
#                                 "name": "Chunichi Dragons",
#                                 "price": 2.17
#                             },
#                             {
#                                 "name": "Yokohama DeNA BayStars",
#                                 "price": 1.72
#                             }
#                         ]
#                     }
#                 ]
#             },
#             {
#                 "key": "boylesports",
#                 "title": "BoyleSports",
#                 "last_update": "2024-05-19T02:31:58Z",
#                 "markets": [
#                     {
#                         "key": "h2h",
#                         "last_update": "2024-05-19T02:31:58Z",
#                         "outcomes": [
#                             {
#                                 "name": "Chunichi Dragons",
#                                 "price": 2.1
#                             },
#                             {
#                                 "name": "Yokohama DeNA BayStars",
#                                 "price": 1.67
#                             }
#                         ]
#                     }
#                 ]
#             },
#             {
#                 "key": "coral",
#                 "title": "Coral",
#                 "last_update": "2024-05-19T02:33:55Z",
#                 "markets": [
#                     {
#                         "key": "h2h",
#                         "last_update": "2024-05-19T02:33:55Z",
#                         "outcomes": [
#                             {
#                                 "name": "Chunichi Dragons",
#                                 "price": 2.0
#                             },
#                             {
#                                 "name": "Yokohama DeNA BayStars",
#                                 "price": 1.75
#                             }
#                         ]
#                     },
#                     {
#                         "key": "spreads",
#                         "last_update": "2024-05-19T02:33:55Z",
#                         "outcomes": [
#                             {
#                                 "name": "Chunichi Dragons",
#                                 "price": 2.8,
#                                 "point": -1.5
#                             },
#                             {
#                                 "name": "Yokohama DeNA BayStars",
#                                 "price": 1.4,
#                                 "point": 1.5
#                             }
#                         ]
#                     },
#                     {
#                         "key": "totals",
#                         "last_update": "2024-05-19T02:33:55Z",
#                         "outcomes": [
#                             {
#                                 "name": "Over",
#                                 "price": 1.95,
#                                 "point": 6.5
#                             },
#                             {
#                                 "name": "Under",
#                                 "price": 1.75,
#                                 "point": 6.5
#                             }
#                         ]
#                     }
#                 ]
#             }
#         ]
#     },
#     {
#         "id": "f4560118338eda5eb1fb6c06a44fd19b",
#         "sport_key": "baseball_kbo",
#         "sport_title": "KBO",
#         "commence_time": "2024-05-19T05:00:00Z",
#         "home_team": "Doosan Bears",
#         "away_team": "Lotte Giants",
#         "bookmakers": [
#             {
#                 "key": "livescorebet",
#                 "title": "LiveScore Bet",
#                 "last_update": "2024-05-19T02:33:55Z",
#                 "markets": [
#                     {
#                         "key": "h2h",
#                         "last_update": "2024-05-19T02:33:55Z",
#                         "outcomes": [
#                             {
#                                 "name": "Doosan Bears",
#                                 "price": 1.36
#                             },
#                             {
#                                 "name": "Lotte Giants",
#                                 "price": 3.1
#                             }
#                         ]
#                     },
#                     {
#                         "key": "totals",
#                         "last_update": "2024-05-19T02:33:55Z",
#                         "outcomes": [
#                             {
#                                 "name": "Over",
#                                 "price": 1.85,
#                                 "point": 9.0
#                             },
#                             {
#                                 "name": "Under",
#                                 "price": 1.85,
#                                 "point": 9.0
#                             }
#                         ]
#                     }
#                 ]
#             },
#             {
#                 "key": "betfair_sb_uk",
#                 "title": "Betfair Sportsbook",
#                 "last_update": "2024-05-19T02:33:55Z",
#                 "markets": [
#                     {
#                         "key": "h2h",
#                         "last_update": "2024-05-19T02:33:55Z",
#                         "outcomes": [
#                             {
#                                 "name": "Doosan Bears",
#                                 "price": 1.33
#                             },
#                             {
#                                 "name": "Lotte Giants",
#                                 "price": 3.0
#                             }
#                         ]
#                     }
#                 ]
#             },
#             {
#                 "key": "betway",
#                 "title": "Betway",
#                 "last_update": "2024-05-19T02:32:46Z",
#                 "markets": [
#                     {
#                         "key": "h2h",
#                         "last_update": "2024-05-19T02:32:46Z",
#                         "outcomes": [
#                             {
#                                 "name": "Doosan Bears",
#                                 "price": 1.33
#                             },
#                             {
#                                 "name": "Lotte Giants",
#                                 "price": 3.0
#                             }
#                         ]
#                     }
#                 ]
#             },
#             {
#                 "key": "williamhill",
#                 "title": "William Hill",
#                 "last_update": "2024-05-19T02:31:58Z",
#                 "markets": [
#                     {
#                         "key": "h2h",
#                         "last_update": "2024-05-19T02:31:58Z",
#                         "outcomes": [
#                             {
#                                 "name": "Doosan Bears",
#                                 "price": 1.36
#                             },
#                             {
#                                 "name": "Lotte Giants",
#                                 "price": 3.0
#                             }
#                         ]
#                     }
#                 ]
#             },
#             {
#                 "key": "boylesports",
#                 "title": "BoyleSports",
#                 "last_update": "2024-05-19T02:33:22Z",
#                 "markets": [
#                     {
#                         "key": "h2h",
#                         "last_update": "2024-05-19T02:33:22Z",
#                         "outcomes": [
#                             {
#                                 "name": "Doosan Bears",
#                                 "price": 1.36
#                             },
#                             {
#                                 "name": "Lotte Giants",
#                                 "price": 3.0
#                             }
#                         ]
#                     }
#                 ]
#             },
#             {
#                 "key": "coral",
#                 "title": "Coral",
#                 "last_update": "2024-05-19T02:33:55Z",
#                 "markets": [
#                     {
#                         "key": "h2h",
#                         "last_update": "2024-05-19T02:33:55Z",
#                         "outcomes": [
#                             {
#                                 "name": "Doosan Bears",
#                                 "price": 1.36
#                             },
#                             {
#                                 "name": "Lotte Giants",
#                                 "price": 2.87
#                             }
#                         ]
#                     },
#                     {
#                         "key": "spreads",
#                         "last_update": "2024-05-19T02:33:55Z",
#                         "outcomes": [
#                             {
#                                 "name": "Doosan Bears",
#                                 "price": 1.2,
#                                 "point": 1.5
#                             },
#                             {
#                                 "name": "Lotte Giants",
#                                 "price": 4.0,
#                                 "point": -1.5
#                             }
#                         ]
#                     },
#                     {
#                         "key": "totals",
#                         "last_update": "2024-05-19T02:33:55Z",
#                         "outcomes": [
#                             {
#                                 "name": "Over",
#                                 "price": 2.05,
#                                 "point": 9.5
#                             },
#                             {
#                                 "name": "Under",
#                                 "price": 1.67,
#                                 "point": 9.5
#                             }
#                         ]
#                     }
#                 ]
#             }
#         ]
#     }
# ]
# Remaining requests 329
# Used requests 171

# %%
# Event object == individual sporting event
class Event:
    def __init__(self, data):
        self.data = data
        self.sport_key = data['sport_key']
        self.id = data['id']

    def num_of_outcomes(self):  # Might need to change this unsure
        bookmakers = self.data['bookmakers']
        total = []
        for bookmaker in bookmakers:
            odds = bookmaker['markets'][0]['outcomes']
            total.extend(odds)

        num_outcomes = len(total) # I think this is currently counting every possible outcome
        return num_outcomes

    def pull_odds(self): #
        master_list = []

        bookmakers = self.data['bookmakers']
        for bookmaker in bookmakers:
            odds = bookmaker['markets'][0]['outcomes']

            for outcome in odds:

                team_name = outcome['name']
                odds_price = outcome['price']
                bookie = bookmaker['title']

                info = {
                    "team name": team_name,
                    "odds" : odds_price,
                    "bookmaker" : bookie,
                }
                
                master_list.append(info)
        return master_list
    
    def calculate_best_odds(self, list): # | list = master_list 

        outcome_1_name = None
        outcome_2_name = None
        outcome_3_name = None

        outcome_1_best_odds = float("-inf")
        outcome_2_best_odds = float("-inf")
        outcome_3_best_odds = float("-inf")

        outcome_1_bookmaker = None
        outcome_2_bookmaker = None
        outcome_3_bookmaker = None

        for outcome in range(len(list)):
            
            if outcome_1_name is None or outcome_1_name == list[outcome]['team name']:
                outcome_1_name = list[outcome]['team name']
                if list[outcome]['odds'] > outcome_1_best_odds:
                    outcome_1_best_odds = list[outcome]['odds']
                    outcome_1_bookmaker = list[outcome]['bookmaker']
            
            elif outcome_2_name is None or outcome_2_name == list[outcome]['team name']:
                outcome_2_name = list[outcome]['team name']
                if list[outcome]['odds'] > outcome_2_best_odds:
                    outcome_2_best_odds = list[outcome]['odds']
                    outcome_2_bookmaker = list[outcome]['bookmaker']
            
            if outcome_3_name is None and outcome_1_name != list[outcome]['team name'] and outcome_2_name != list[outcome]['team name']:
                outcome_3_name = list[outcome]['team name']

            if outcome_3_name == list[outcome]['team name']:
                if list[outcome]['odds'] > outcome_3_best_odds:
                    outcome_3_best_odds = list[outcome]['odds']
                    outcome_3_bookmaker = list[outcome]['bookmaker']

        return [[outcome_1_name, outcome_1_best_odds, outcome_1_bookmaker], [outcome_2_name, outcome_2_best_odds, outcome_2_bookmaker], [outcome_3_name, outcome_3_best_odds, outcome_3_bookmaker]]

        # Find best odds for each outcome of a matchup and return the [Team, Odds, Bookie] for each outcome

    # Calculate arbitrage | Boolean
    def calculate_arbitrage(self, best_odds_list):
        # If only 2 outcomes remove the 3rd item
        if best_odds_list[2][0] == None:
            best_odds_list.pop(2)
        else:
            return None # Will add 3 way arb

        odds_outcome_1 = best_odds_list[0][1]
        odds_outcome_2 = best_odds_list[1][1]

        arbitrage = ((1 / odds_outcome_1) * 100) + ((1 / odds_outcome_2) * 100)
        
        return arbitrage
    
    def arbitrage_present(self, arb):
        if arb == None:
            return None # Get rid of this after adding 3 way arb
        return arb < 100
    
    def american_to_decimal(self, american_odds):
        if american_odds > 0:
            return (american_odds / 100) + 1
        elif american_odds < 0:
            return (100 / american_odds) + 1
        else:
            return None # invalid odds
        
    def decimal_to_american(self, decimal_odds):
        if decimal_odds >= 2:
            return (decimal_odds - 1) * 100
        elif 1.01 <= decimal_odds < 2:
            return -100 / (decimal_odds - 1)
        else:
            return None # invalid odds
        
    # Calculate arbitrage bet return | [Multiplier]
    def arbitrage_bet_return(self, bet_amount, arbitrage_percent):
        if arbitrage_percent == None:
            return None
        return (bet_amount / (arbitrage_percent / 100)) - bet_amount
    
    
    def calculate_bets_and_profit(self, bet_amount, best_odds_list):
        odds_outcome_1 = best_odds_list[0][1]
        odds_outcome_2 = best_odds_list[1][1]

        # Calculate the total amount to bet on each outcome
        bet_outcome_1 = (bet_amount * (1 / odds_outcome_1)) / ((1 / odds_outcome_1) + (1 / odds_outcome_2))
        bet_outcome_2 = bet_amount - bet_outcome_1

        # Calculate profit
        profit = min(bet_outcome_1 * odds_outcome_1 - bet_amount, bet_outcome_2 * odds_outcome_2 - bet_amount)

        return bet_outcome_1, bet_outcome_2, profit
    
    def send_to_discord(self, webhook_url, message):
        data = {
            "content": message
        }
        response = requests.post(webhook_url, json=data)
        if response.status_code == 204:
            print("Message sent successfully")
        else:
            print(f"Failed to send message: {response.status_code}")

# %%
webhook_url = '' #insert discod webhook

for i in range(len(odds_json)):
    game = Event(odds_json[i])
    master_list = game.pull_odds()
    num_outcomes = game.num_of_outcomes()
    odds = game.calculate_best_odds(master_list)
    arb = game.calculate_arbitrage(odds)

    if game.arbitrage_present(arb):
        print("Arbitrage Opportunity Found!")
        print(f"Best odds: {odds}")
        print(f"Decimal Odds: {odds[0][1]} and {odds[1][1]}")
        
        bet_outcome_1, bet_outcome_2, profit = game.calculate_bets_and_profit(100, odds)
        print(f"Bet Amounts: {bet_outcome_1:.2f} on {odds[0][0]}, {bet_outcome_2:.2f} on {odds[1][0]}")
        print(f"Profit: {profit:.2f}\n")
        
#     if game.arbitrage_present(arb):
#         print("found")
#         print(odds)
#         print(game.american_to_decimal(round(odds[0][1], 0)))
#         print(game.american_to_decimal(round(odds[1][1], 0)))
#         print(round(game.arbitrage_bet_return(100, arb), 2)) # Gives money return for $100 totbal bets
# Out:
# Arbitrage Opportunity Found!
# Best odds: [['Los Angeles Angels', 2.08, 'Betfair'], ['Texas Rangers', 2.18, 'Casumo']]
# Decimal Odds: 2.08 and 2.18
# Bet Amounts: 51.17 on Los Angeles Angels, 48.83 on Texas Rangers
# Profit: 6.44
#
# Arbitrage Opportunity Found!
# Best odds: [[None, -inf, None], [None, -inf, None]]
# Decimal Odds: -inf and -inf
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Input In [91], in <cell line: 3>()
#      12 print(f"Best odds: {odds}")
#      13 print(f"Decimal Odds: {odds[0][1]} and {odds[1][1]}")
# ---> 15 bet_outcome_1, bet_outcome_2, profit = game.calculate_bets_and_profit(100, odds)
#      16 print(f"Bet Amounts: {bet_outcome_1:.2f} on {odds[0][0]}, {bet_outcome_2:.2f} on {odds[1][0]}")
#      17 print(f"Profit: {profit:.2f}\n")
#
# Input In [90], in Event.calculate_bets_and_profit(self, bet_amount, best_odds_list)
#     125 odds_outcome_2 = best_odds_list[1][1]
#     127 # Calculate the total amount to bet on each outcome
# --> 128 bet_outcome_1 = (bet_amount * (1 / odds_outcome_1)) / ((1 / odds_outcome_1) + (1 / odds_outcome_2))
#     129 bet_outcome_2 = bet_amount - bet_outcome_1
#     131 # Calculate profit
#
# ZeroDivisionError: float division by zero

# %%
webhook_url = '' #insert discord webhook 

for i in range(len(odds_json)):
    game = Event(odds_json[i])
    master_list = game.pull_odds()
    num_outcomes = game.num_of_outcomes()
    odds = game.calculate_best_odds(master_list)
    arb = game.calculate_arbitrage(odds)

    if game.arbitrage_present(arb):
        print("Arbitrage Opportunity Found!")
        print(f"Best odds: {odds}")
        print(f"Decimal Odds: {odds[0][1]} and {odds[1][1]}")
        
        bet_outcome_1, bet_outcome_2, profit = game.calculate_bets_and_profit(100, odds)
        print(f"Bet Amounts: {bet_outcome_1:.2f} on {odds[0][0]}, {bet_outcome_2:.2f} on {odds[1][0]}")
        print(f"Profit: {profit:.2f}")
        
        game.send_to_discord(webhook_url,
            f"Arbitrage Opportunity Found!\n"
            f"Best odds: {odds}\n"
            f"Decimal Odds: {odds[0][1]} and {odds[1][1]}\n"
            f"Bet Amounts: {bet_outcome_1:.2f} on {odds[0][0]}, {bet_outcome_2:.2f} on {odds[1][0]}\n"
            f"Profit: {profit:.2f}\n")
